# %%
#Q1  Count frequencies of various alphabets (Convert upper case into lower case and input given byuser), plot the results for this as a bar chart with x-axis being the letter and y-axis as the corresponding frequency.

import matplotlib.pyplot as plt

# Function to count frequencies of alphabets
def count_alphabet_frequency(text):
    frequencies = {}
    for char in text:
        if char.isalpha():
            char = char.lower()
            frequencies[char] = frequencies.get(char, 0) + 1
    return frequencies

# Get input from user
user_input = input("Enter a string: ")

# Count alphabet frequencies
alphabet_frequencies = count_alphabet_frequency(user_input)

# Plot the results as a bar chart
plt.figure(figsize=(10, 6))
plt.bar(alphabet_frequencies.keys(), alphabet_frequencies.values(), color='skyblue')
plt.title('Alphabet Frequency')
plt.xlabel('Alphabet')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Q2  Use the following data to plot the number of applicant per year as a scatter plot. year = [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]
#  No_of_ applications_ per_ year = [921261, 929198, 1043739, 1186454, 1194938, 1304495, 1356805,1282000, 479651]


import matplotlib.pyplot as plt

# Data
year = [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]
no_of_applications_per_year = [921261, 929198, 1043739, 1186454, 1194938, 1304495, 1356805, 1282000, 479651]


plt.scatter(year, no_of_applications_per_year, color='blue', marker='o')

# %%
#Q3 Plot xsinx,x2 sinx,x3 sinxandx4 sinxinasingleplotintherangex∈[−10,10].

import numpy as np
import matplotlib.pyplot as plt

plt.plot(x, y1, label=r'$x\sin(x)$')
plt.plot(x, y2, label=r'$x^2\sin(x)$')
plt.plot(x, y3, label=r'$x^3\sin(x)$')
plt.plot(x, y4, label=r'$x^4\sin(x)$')

plt.title('Plot of x*sin(x), x^2*sin(x), x^3*sin(x), and x^4*sin(x)')
# Out:
# Text(0.5, 1.0, 'Plot of x*sin(x), x^2*sin(x), x^3*sin(x), and x^4*sin(x)')

# %%
#Q4  plot histogram for age of male and female in different plots for the following data of male
#      and female age.
#      male age = [53,51,71,31,33,39,52,27,54,30,64,26,21,54,52,20,59,32]
#     female age = [53,65,68,21,75,46,24,63,61,24,49,41,39,40,25,54,42, 32,48,23,23]


import matplotlib.pyplot as plt

# Data
male_age = [53, 51, 71, 31, 33, 39, 52, 27, 54, 30, 64, 26, 21, 54, 52, 20, 59, 32]
female_age = [53, 65, 68, 21, 75, 46, 24, 63, 61, 24, 49, 41, 39, 40, 25, 54, 42, 32, 48, 23, 23]

# Plot histograms for male and female ages
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.hist(male_age, bins=10, color='blue', edgecolor='black')
# plt.title('Histogram of Male Ages')
# plt.xlabel('Age')
# plt.ylabel('Frequency')

plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.hist(female_age, bins=10, color='red', edgecolor='black')
plt.title('Histogram of Female Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
