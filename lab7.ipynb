# %%
#Q1. Download CANCER data set from kaggle(Cancer Patients Data (kaggle.com)
#     (We have downloaded and attached the csv file for your reference)

import pandas as pd
cancer=pd.read_csv('/Users/sauravkumararya/Downloads/cancerdataset1.csv')
cancer
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
#Q2 Create a dataframe with the file

import pandas as pd

# Specify the file path where your CSV file is located
file_path = '/Users/sauravkumararya/Downloads/cancerdataset1.csv'

# Load the CSV file into a DataFrame
cancer_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify
print(cancer_df.head())
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
#Q3. Create a variable X to hold the input columns(columns 1-23)

import pandas as pd

# Specify the file path where your CSV file is located
file_path = '/Users/sauravkumararya/Downloads/cancerdataset1.csv'

# Load the CSV file into a DataFrame
cancer_df = pd.read_csv(file_path)

# Select columns 1 to 23 as input features (assuming columns are 0-indexed)
input_columns = cancer_df.columns[1:24]  # Columns 1-23 (0-indexed)

# Create the variable X containing the selected input columns
X = cancer_df[input_columns]

# Display the first few rows of X to verify
print(X.head())
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Coughing of Blood  Fatigue  Weight Loss  Shortness of Breath  \
# 0        4  ...                  4        3            4                    2
# ...

# %%
#Q4. Create a variable Y to hold the Level column

# %%
#Q5  Apply PCA on X

import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Specify the file path where your CSV file is located
file_path = '/Users/sauravkumararya/Downloads/cancerdataset1.csv'

# Load the CSV file into a DataFrame
cancer_df = pd.read_csv(file_path)

# Select columns 1 to 23 as input features (assuming columns are 0-indexed)
input_columns = cancer_df.columns[1:24]  # Columns 1-23 (0-indexed)
X = cancer_df[input_columns]

# Standardize the input features (important for PCA)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA with desired number of components (e.g., 2 for visualization)
n_components = 2  # Number of principal components
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# Plot the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
plt.bar(range(n_components), explained_variance_ratio, alpha=0.5, align='center')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Component')
plt.show()

# Display the transformed data with reduced dimensions
print(f"Original shape of X: {X.shape}")
print(f"Shape of X after PCA: {X_pca.shape}")
# Out:
# Original shape of X: (1000, 23)
# Shape of X after PCA: (1000, 2)

# %%
#Q6  Apply kNN classification on the principal components to predict the level of the cancer for apatient(0/1/2)

# %%
#Q7  Apply k-means clustering for this dataset(i.e, X) to form 3 clusters

import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Specify the file path where your CSV file is located
file_path = '/Users/sauravkumararya/Downloads/cancerdataset1.csv'

# Load the CSV file into a DataFrame
cancer_df = pd.read_csv(file_path)

# Select columns 1 to 23 as input features (assuming columns are 0-indexed)
input_columns = cancer_df.columns[1:24]  # Columns 1-23 (0-indexed)
X = cancer_df[input_columns]

# Standardize the input features (important for clustering)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to reduce dimensionality (optional for visualization)
n_components = 2  # Number of principal components for visualization
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# Apply k-means clustering with 3 clusters
n_clusters = 3  # Number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(X_scaled)

# Visualize the clusters (using PCA for 2D visualization)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis', alpha=0.5)
plt.title(f'k-means Clustering with {n_clusters} Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster Label')
plt.show()

# Assign cluster labels to the original DataFrame
cancer_df['Cluster'] = cluster_labels

# Display the count of samples in each cluster
print(cancer_df['Cluster'].value_counts())
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster
# 0    445
# 2    375
# 1    180
# Name: count, dtype: int64

# %%
#Q8  Predict the target cluster for every row of X and compare it with actual Y using confusion matrix
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 21
# ...
